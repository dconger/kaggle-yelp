# %%
from __future__ import division
from dateutil.parser import parse
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import time
import datetime

# %%
review_df = pd.read_csv('../data/yelp_training_set_review.csv',
                     converters={'date': parse}).set_index('review_id')

# %%
review_df.sample(n=3)
# Out:
#                                    business_id       date  stars  \
# review_id
# 44F8TSvTYOPxy_HdbWfT0Q  MJ6_uOT55dq5ALphFqMVkw 2010-07-10      5
# iaBPXWJ7Zlcfq26AB8LpdQ  eGevCRobYnA_HSj60sEWvQ 2011-06-15      5
# cBwDd4vVMt6d_cf3dqxHcQ  r3r_bAfa6pZKIhQB82FizQ 2009-04-07      1
#
#                                                                      text  \
# review_id
# 44F8TSvTYOPxy_HdbWfT0Q  I've been a long-time lover of Lenny's for sev...
# iaBPXWJ7Zlcfq26AB8LpdQ  Pita Jungle is my gold standard for Mediterran...
# cBwDd4vVMt6d_cf3dqxHcQ  Overhyped!!\n\nYeah,  the Chef and manager are...
#
#                           type                 user_id  votes_cool  \
# review_id
# 44F8TSvTYOPxy_HdbWfT0Q  review  AtnYGQjNY2cCSNWt_LY8nQ           0
# iaBPXWJ7Zlcfq26AB8LpdQ  review  QYXQ_M4-U6ptDMHtcRi9kQ           0
# cBwDd4vVMt6d_cf3dqxHcQ  review  xs_fnNe0hofd7ZOupCjesQ           7
#
#                         votes_funny  votes_useful
# review_id
# 44F8TSvTYOPxy_HdbWfT0Q            0             1
# iaBPXWJ7Zlcfq26AB8LpdQ            0             0
# cBwDd4vVMt6d_cf3dqxHcQ            7            15

# %%
user_df = pd.read_csv('../data/yelp_training_set_user.csv').set_index('user_id')
user_df.sample(n=3)
# Out:
#                         average_stars   name  review_count  type  votes_cool  \
# user_id
# mB7533hZM30GIULkWFBfhQ           3.71  Chris            14  user           4
# iFTGCeal_5GbRxZvgX7hHg           4.00    Ben             7  user           1
# B7VtyrGlLC43FcGQUmNgwQ           3.60    Ray            30  user          11
#
#                         votes_funny  votes_useful
# user_id
# mB7533hZM30GIULkWFBfhQ            4            16
# iFTGCeal_5GbRxZvgX7hHg            0             4
# B7VtyrGlLC43FcGQUmNgwQ            7            22

# %%
business_df = pd.read_csv('../data/yelp_training_set_business.csv').set_index('business_id')
business_df.sample(n=2)
# Out:
#                                                                categories  \
# business_id
# j8NI4Dd9ANuyrMZ8vTN1eA               Hotels & Travel,Taxis,Transportation
# eSEguR3D17fYgVHU3Y6cxQ  Reflexology,Health & Medical,Massage,Beauty & ...
#
#                               city  \
# business_id
# j8NI4Dd9ANuyrMZ8vTN1eA  Scottsdale
# eSEguR3D17fYgVHU3Y6cxQ  Scottsdale
#
#                                                              full_address  \
# business_id
# j8NI4Dd9ANuyrMZ8vTN1eA                               Scottsdale, AZ 85251
# eSEguR3D17fYgVHU3Y6cxQ  2765 N Scottsdale Rd\nSte 104\nScottsdale, AZ ...
#
#                          latitude   longitude            name  neighborhoods  \
# business_id
# j8NI4Dd9ANuyrMZ8vTN1eA  33.479298 -111.959480  Big Orange Bus            NaN
# eSEguR3D17fYgVHU3Y6cxQ  33.478794 -111.925909      Just Relax            NaN
#
#                         open  review_count  stars state      type
# business_id
# j8NI4Dd9ANuyrMZ8vTN1eA  True             4    4.0    AZ  business
# eSEguR3D17fYgVHU3Y6cxQ  True            22    4.5    AZ  business

# %%
# Sort by most reviews
business_df.sort_values(by='review_count', ascending=False)[:3]
# Out:
#                                                                categories  \
# business_id
# hW0Ne_HTHEAgGF1rAdmR-g                           Hotels & Travel,Airports
# VVeogjZya58oiTxK7qUjAQ                                  Pizza,Restaurants
# JokKtdXU7zXHcr20Lrk29A  Bars,Food,Breweries,Pubs,Nightlife,American (N...
#
#                            city                               full_address  \
# business_id
# hW0Ne_HTHEAgGF1rAdmR-g  Phoenix  3400 E Sky Harbor Blvd\nPhoenix, AZ 85034
# VVeogjZya58oiTxK7qUjAQ  Phoenix          623 E Adams St\nPhoenix, AZ 85004
# JokKtdXU7zXHcr20Lrk29A    Tempe    1340 E 8th St\nSte 104\nTempe, AZ 85281
#
#                          latitude   longitude  \
# business_id
# hW0Ne_HTHEAgGF1rAdmR-g  33.434750 -112.006440
# VVeogjZya58oiTxK7qUjAQ  33.449233 -112.065458
# JokKtdXU7zXHcr20Lrk29A  33.419451 -111.915926
#
#                                                             name  \
# business_id
# hW0Ne_HTHEAgGF1rAdmR-g  Phoenix Sky Harbor International Airport
# VVeogjZya58oiTxK7qUjAQ                           Pizzeria Bianco
# JokKtdXU7zXHcr20Lrk29A                     Four Peaks Brewing Co
#
#                         neighborhoods  open  review_count  stars state  \
# business_id
# hW0Ne_HTHEAgGF1rAdmR-g            NaN  True           862    3.0    AZ
# VVeogjZya58oiTxK7qUjAQ            NaN  True           803    4.0    AZ
# JokKtdXU7zXHcr20Lrk29A            NaN  True           735    4.5    AZ
#
#                             type
# business_id
# hW0Ne_HTHEAgGF1rAdmR-g  business
# VVeogjZya58oiTxK7qUjAQ  business
# JokKtdXU7zXHcr20Lrk29A  business

# %%
# Add more features to review DataFrame
review_df['text'] = review_df['text'].fillna("")
review_df['review_length'] = review_df['text'].apply(len)
review_df[:2]
# Look at the relationship between review length and # of useful votes
# Out:
#                                    business_id       date  stars  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  9yKzy9PApeiPPOUJEtnvkg 2011-01-26      5
# IjZ33sJrzXqU-0X6U8NwyA  ZRJwVLyzEJq1VAihDhYiow 2011-07-27      5
#
#                                                                      text  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  My wife took me here on my birthday for breakf...
# IjZ33sJrzXqU-0X6U8NwyA  I have no idea why some people give bad review...
#
#                           type                 user_id  votes_cool  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  review  rLtl8ZkDX5vH5nAx9C3q5Q           2
# IjZ33sJrzXqU-0X6U8NwyA  review  0a2KyEL0d3Yb1V6aivbIuQ           0
#
#                         votes_funny  votes_useful  review_length
# review_id
# fWKvX83p0-ka4JS3dc6E5A            0             5            889
# IjZ33sJrzXqU-0X6U8NwyA            0             0           1345

# %%
# Stem the text
tokenizer = WordPunctTokenizer() # splits up a document into words
stemmer = PorterStemmer() # takes each token to it's root form (.e.g., goes ==> go)

stopset = set(stopwords.words('english'))

# %%
def tokenize(text):
    return tokenizer.tokenize(text.lower())

def remove_words(arr, min_word_length=3, remove_stopset=True):
    big_words = [w for w in arr if (len(w) >= min_word_length)]
    
    if remove_stopset:
        return [w for w in big_words if w not in stopset]
    else:
        return big_words

def stem_words(arr):
    return [stemmer.stem(word) for word in arr]

def rejoin_text(arr):
    return " ".join([w for w in arr])
# return ";".join(["%s=%s" % (k, v) for k, v in params.items()])

# Pipe: text -> tokenize -> remove_words -> stem_words

# %%
review_df['text_no_stopwords'] = review_df['text'].apply(tokenize).apply(remove_words).apply(rejoin_text)
review_df.head()
# Out:
#                                    business_id       date  stars  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  9yKzy9PApeiPPOUJEtnvkg 2011-01-26      5
# IjZ33sJrzXqU-0X6U8NwyA  ZRJwVLyzEJq1VAihDhYiow 2011-07-27      5
# IESLBzqUCLdSzSqm0eCSxQ  6oRAC4uyJCsJl1X0WZpVSA 2012-06-14      4
# G-WvGaISbqqaMHlNnByodA  _1QQZuf4zZOyFCvXc0o6Vg 2010-05-27      5
# 1uJFq2r5QfJG_6ExMRCaGw  6ozycU1RpktNG2-1BroVtw 2012-01-05      5
#
#                                                                      text  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  My wife took me here on my birthday for breakf...
# IjZ33sJrzXqU-0X6U8NwyA  I have no idea why some people give bad review...
# IESLBzqUCLdSzSqm0eCSxQ  love the gyro plate. Rice is so good and I als...
# G-WvGaISbqqaMHlNnByodA  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...
# 1uJFq2r5QfJG_6ExMRCaGw  General Manager Scott Petello is a good egg!!!...
#
#                           type                 user_id  votes_cool  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  review  rLtl8ZkDX5vH5nAx9C3q5Q           2
# IjZ33sJrzXqU-0X6U8NwyA  review  0a2KyEL0d3Yb1V6aivbIuQ           0
# IESLBzqUCLdSzSqm0eCSxQ  review  0hT2KtfLiobPvh6cDC8JQg           0
# G-WvGaISbqqaMHlNnByodA  review  uZetl9T0NcROGOyFfughhg           1
# 1uJFq2r5QfJG_6ExMRCaGw  review  vYmM4KTsC8ZfQBg-j5MWkw           0
#
#                         votes_funny  votes_useful  review_length  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A            0             5            889
# IjZ33sJrzXqU-0X6U8NwyA            0             0           1345
# IESLBzqUCLdSzSqm0eCSxQ            0             1             76
# G-WvGaISbqqaMHlNnByodA            0             2            419
# 1uJFq2r5QfJG_6ExMRCaGw            0             0            469
#
#                                                         text_no_stopwords
# review_id
# fWKvX83p0-ka4JS3dc6E5A  wife took birthday breakfast excellent weather...
# IjZ33sJrzXqU-0X6U8NwyA  idea people give bad reviews place goes show p...
# IESLBzqUCLdSzSqm0eCSxQ  love gyro plate rice good also dig candy selec...
# G-WvGaISbqqaMHlNnByodA  rosie dakota love chaparral dog park !!! conve...
# 1uJFq2r5QfJG_6ExMRCaGw  general manager scott petello good egg !!! det...

# %%
review_df['review_len_no_stopwords'] = review_df['text_no_stopwords'].apply(len)
review_df.head(3)
# Out:
#                                    business_id       date  stars  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  9yKzy9PApeiPPOUJEtnvkg 2011-01-26      5
# IjZ33sJrzXqU-0X6U8NwyA  ZRJwVLyzEJq1VAihDhYiow 2011-07-27      5
# IESLBzqUCLdSzSqm0eCSxQ  6oRAC4uyJCsJl1X0WZpVSA 2012-06-14      4
#
#                                                                      text  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  My wife took me here on my birthday for breakf...
# IjZ33sJrzXqU-0X6U8NwyA  I have no idea why some people give bad review...
# IESLBzqUCLdSzSqm0eCSxQ  love the gyro plate. Rice is so good and I als...
#
#                           type                 user_id  votes_cool  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  review  rLtl8ZkDX5vH5nAx9C3q5Q           2
# IjZ33sJrzXqU-0X6U8NwyA  review  0a2KyEL0d3Yb1V6aivbIuQ           0
# IESLBzqUCLdSzSqm0eCSxQ  review  0hT2KtfLiobPvh6cDC8JQg           0
#
#                         votes_funny  votes_useful  review_length  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A            0             5            889
# IjZ33sJrzXqU-0X6U8NwyA            0             0           1345
# IESLBzqUCLdSzSqm0eCSxQ            0             1             76
#
#                                                         text_no_stopwords  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  wife took birthday breakfast excellent weather...
# IjZ33sJrzXqU-0X6U8NwyA  idea people give bad reviews place goes show p...
# IESLBzqUCLdSzSqm0eCSxQ  love gyro plate rice good also dig candy selec...
#
#                         review_len_no_stopwords
# review_id
# fWKvX83p0-ka4JS3dc6E5A                      542
# IjZ33sJrzXqU-0X6U8NwyA                      707
# IESLBzqUCLdSzSqm0eCSxQ                       50

# %%
review_df['review_len_uniq'] = review_df['text_no_stopwords'].apply(tokenize).apply(np.unique).apply(len)
review_df.head(1)
# Out:
#                                    business_id       date  stars  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  9yKzy9PApeiPPOUJEtnvkg 2011-01-26      5
#
#                                                                      text  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  My wife took me here on my birthday for breakf...
#
#                           type                 user_id  votes_cool  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  review  rLtl8ZkDX5vH5nAx9C3q5Q           2
#
#                         votes_funny  votes_useful  review_length  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A            0             5            889
#
#                                                         text_no_stopwords  \
# review_id
# fWKvX83p0-ka4JS3dc6E5A  wife took birthday breakfast excellent weather...
#
#                         review_len_no_stopwords  review_len_uniq
# review_id
# fWKvX83p0-ka4JS3dc6E5A                      542               67

# %%
review_df[:1].text_no_stopwords
# Out:
# review_id
# fWKvX83p0-ka4JS3dc6E5A    wife took birthday breakfast excellent weather...
# Name: text_no_stopwords, dtype: object
